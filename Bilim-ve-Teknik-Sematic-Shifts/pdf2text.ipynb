# %%
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io
import os
import re

# %%
# Extracting filenames, directories and years
pdf_dict = {'filename':[], 'year':[], 'dir':[], 'text':[]}
for subdir, dirs, files in os.walk('pdf_files'):
    for file in files:
        pdf_dict['filename'].append(file)
        pdf_dict['year'].append(subdir[-4:])
        pdf_dict['dir'].append(os.path.join(subdir, file))

# %%
#Reading pdfs
def read_pdf(dir_chunk):
    text_chunk = []

    for pdf_dir in dir_chunk:
        resource_manager = PDFResourceManager()
        fake_file_handle = io.StringIO()
        converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
        page_interpreter = PDFPageInterpreter(resource_manager, converter)
        print('Reading: ' + pdf_dir)

        with open(pdf_dir, 'rb') as fh:
            for page in PDFPage.get_pages(fh,
                                          caching=True,
                                          check_extractable=True):

                page_interpreter.process_page(page)

            text = fake_file_handle.getvalue()
            text_chunk.append(text)

        converter.close()
        fake_file_handle.close()
    print('-'*50)
    
    return text_chunk

# %%
# Creating output folders
# categorized by years
def create_folders(year_chunk):
    for year in set(year_chunk):
        out_filename = 'text_files/' + year + '/'
        os.makedirs(os.path.dirname(out_filename), exist_ok=True)

# %%
# Creating txt files
# text_files/year/filename.txt

def write_txt(filename_chunk, year_chunk, text_chunk):
    for filename, year, text in zip(filename_chunk,
                                    year_chunk,
                                    text_chunk):

        txt_name = re.findall('(.*)\.', filename)[0] + '.txt'
        output_path = 'text_files/' + year + '/' + txt_name

        with open(output_path, 'w') as output:
            output.write(text)

# %%
## Partitioning to not exceed recursion limit
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

chunked_dir = list(chunks(pdf_dict['dir'], 12))
chunked_year = list(chunks(pdf_dict['year'], 12))
chunked_filename = list(chunks(pdf_dict['filename'], 12))

# %%
for c in range(len(chunked_dir)):
    print(f'Batch: {c}')
    text_chunk = read_pdf(chunked_dir[c])
    create_folders(chunked_year[c])
    write_txt(chunked_filename[c], chunked_year[c], text_chunk)
# Out:
# Batch: 0
# Reading: pdf_files/2015/ekim-2015.pdf
# Reading: pdf_files/2015/kasim-2015.pdf
# Reading: pdf_files/2015/ocak-2015.pdf
# Reading: pdf_files/2015/subat-2015.pdf
# Reading: pdf_files/2015/haziran-2015.pdf
# Reading: pdf_files/2015/agustos-2015.pdf
# Reading: pdf_files/2015/mart-2015.pdf
# Reading: pdf_files/2015/nisan-2015.pdf
# Reading: pdf_files/2015/aralik-2015.pdf
# Reading: pdf_files/2015/temmuz-2015.pdf
# Reading: pdf_files/2015/mayis-2015.pdf
# Reading: pdf_files/2015/eylul-2015.pdf
# --------------------------------------------------
# Batch: 1
# Reading: pdf_files/1999/mayis-1999.pdf
# Reading: pdf_files/1999/ekim-1999.pdf
# Reading: pdf_files/1999/ocak-1999.pdf
# Reading: pdf_files/1999/nisan-1999.pdf
# Reading: pdf_files/1999/agustos-1999.pdf
# Reading: pdf_files/1999/aralik-1999.pdf
# Reading: pdf_files/1999/subat-1999.pdf
# Reading: pdf_files/1999/haziran-1999.pdf
# Reading: pdf_files/1999/temmuz-1999.pdf
# Reading: pdf_files/1999/mart-1999.pdf
# Reading: pdf_files/1999/eylul-1999.pdf
# Reading: pdf_files/1999/kasim-1999.pdf
# --------------------------------------------------
# Batch: 2
# Reading: pdf_files/2003/subat-2003.pdf
# Reading: pdf_files/2003/ocak-2003.pdf
# Reading: pdf_files/2003/nisan-2003.pdf
# Reading: pdf_files/2003/mayis-2003.pdf
# Reading: pdf_files/2003/eylul-2003.pdf
# Reading: pdf_files/2003/ekim-2003.pdf
# Reading: pdf_files/2003/haziran-2003.pdf
# Reading: pdf_files/2003/kasim-2003.pdf
# Reading: pdf_files/2003/agustos-2003.pdf
# Reading: pdf_files/2003/temmuz-2003.pdf
# Reading: pdf_files/2003/mart-2003.pdf
# Reading: pdf_files/2003/aralik-2003.pdf
# --------------------------------------------------
# Batch: 3
# Reading: pdf_files/2006/aralik-2006.pdf
# Reading: pdf_files/2006/kasim-2006.pdf
# Reading: pdf_files/2006/subat-2006.pdf
# Reading: pdf_files/2006/mayis-2006.pdf
# Reading: pdf_files/2006/ocak-2006.pdf
# Reading: pdf_files/2006/haziran-2006.pdf
# Reading: pdf_files/2006/ekim-2006.pdf
# Reading: pdf_files/2006/temmuz-2006.pdf
# Reading: pdf_files/2006/eylul-2006.pdf
# Reading: pdf_files/2006/agustos-2006.pdf
# Reading: pdf_files/2006/nisan-2006.pdf
# Reading: pdf_files/2006/mart-2006.pdf
# --------------------------------------------------
# Batch: 4
# Reading: pdf_files/2002/ocak-2002.pdf
# Reading: pdf_files/2002/subat-2002.pdf
# Reading: pdf_files/2002/haziran-2002.pdf
# Reading: pdf_files/2002/ekim-2002.pdf
# Reading: pdf_files/2002/temmuz-2002.pdf
# Reading: pdf_files/2002/eylul-2002.pdf
# Reading: pdf_files/2002/mayis-2002.pdf
# Reading: pdf_files/2002/aralik-2002.pdf
# Reading: pdf_files/2002/nisan-2002.pdf
# Reading: pdf_files/2002/mart-2002.pdf
# Reading: pdf_files/2002/kasim-2002.pdf
# Reading: pdf_files/2002/agustos-2002.pdf
# --------------------------------------------------
# Batch: 5
# Reading: pdf_files/2011/eylul-2011.pdf
# Reading: pdf_files/2011/mart-2011.pdf
# Reading: pdf_files/2011/subat-2011.pdf
# Reading: pdf_files/2011/agustos-2011.pdf
# Reading: pdf_files/2011/mayis-2011.pdf
# Reading: pdf_files/2011/kasim-2011.pdf
# Reading: pdf_files/2011/haziran-2011.pdf
# Reading: pdf_files/2011/nisan-2011.pdf
# Reading: pdf_files/2011/ocak-2011.pdf
# Reading: pdf_files/2011/aralik-2011.pdf
# Reading: pdf_files/2011/ekim-2011.pdf
# Reading: pdf_files/2011/temmuz-2011.pdf
# --------------------------------------------------
# Batch: 6
# Reading: pdf_files/2020/mart-2020.pdf
# Reading: pdf_files/2020/subat-2020.pdf
# Reading: pdf_files/2020/ocak-2020.pdf
# Reading: pdf_files/2000/mayis-2000.pdf
# Reading: pdf_files/2000/nisan-2000.pdf
# Reading: pdf_files/2000/kasim-2000.pdf
# Reading: pdf_files/2000/agustos-2000.pdf
# Reading: pdf_files/2000/eylul-2000.pdf
# Reading: pdf_files/2000/mart-2000.pdf
# Reading: pdf_files/2000/haziran-2000.pdf
# Reading: pdf_files/2000/ekim-2000.pdf
# Reading: pdf_files/2000/subat-2000.pdf
# --------------------------------------------------
# Batch: 7
# Reading: pdf_files/2000/temmuz-2000.pdf
# Reading: pdf_files/2000/ocak-2000.pdf
# Reading: pdf_files/2000/aralik-2000.pdf
# Reading: pdf_files/2013/ocak-2013.pdf
# Reading: pdf_files/2013/temmuz-2013.pdf
# Reading: pdf_files/2013/haziran-2013.pdf
# Reading: pdf_files/2013/subat-2013.pdf
# Reading: pdf_files/2013/mayis-2013.pdf
# Reading: pdf_files/2013/eylul-2013.pdf
# Reading: pdf_files/2013/mart-2013.pdf
# Reading: pdf_files/2013/aralik-2013.pdf
# Reading: pdf_files/2013/agustos-2013.pdf
# --------------------------------------------------
# Batch: 8
# Reading: pdf_files/2013/kasim-2013.pdf
# Reading: pdf_files/2013/ekim-2013.pdf
# Reading: pdf_files/2013/nisan-2013.pdf
# Reading: pdf_files/2007/haziran-2007.pdf
# Reading: pdf_files/2007/kasim-2007.pdf
# Reading: pdf_files/2007/temmuz-2007.pdf
# Reading: pdf_files/2007/mayis-2007.pdf
# Reading: pdf_files/2007/aralik-2007.pdf
# Reading: pdf_files/2007/nisan-2007.pdf
# Reading: pdf_files/2007/subat-2007.pdf
# Reading: pdf_files/2007/agustos-2007.pdf
# Reading: pdf_files/2007/mart-2007.pdf
# --------------------------------------------------
# Batch: 9
# Reading: pdf_files/2007/ocak-2007.pdf
# Reading: pdf_files/2007/ekim-2007.pdf
# Reading: pdf_files/2007/eylul-2007.pdf
# Reading: pdf_files/2008/kasim-2008.pdf
# Reading: pdf_files/2008/haziran-2008.pdf
# Reading: pdf_files/2008/temmuz-2008.pdf
# Reading: pdf_files/2008/ekim-2008.pdf
# Reading: pdf_files/2008/eylul-2008.pdf
# Reading: pdf_files/2008/nisan-2008.pdf
# Reading: pdf_files/2008/mart-2008.pdf
# Reading: pdf_files/2008/mayis-2008.pdf
# Reading: pdf_files/2008/agustos-2008.pdf
# --------------------------------------------------
# Batch: 10
# Reading: pdf_files/2008/subat-2008.pdf
# Reading: pdf_files/2008/ocak-2008.pdf
# Reading: pdf_files/2008/aralik-2008.pdf
# Reading: pdf_files/2017/eylul-2017.pdf
# Reading: pdf_files/2017/temmuz-2017.pdf
# Reading: pdf_files/2017/mart-2017.pdf
# Reading: pdf_files/2017/ekim-2017.pdf
# Reading: pdf_files/2017/haziran-2017.pdf
# Reading: pdf_files/2017/nisan-2017.pdf
# Reading: pdf_files/2017/ocak-2017.pdf
# Reading: pdf_files/2017/agustos-2017.pdf
# Reading: pdf_files/2017/kasim-2017.pdf
# --------------------------------------------------
# Batch: 11
# Reading: pdf_files/2017/subat-2017.pdf
# Reading: pdf_files/2017/aralik-2017.pdf
# Reading: pdf_files/2017/mayis-2017.pdf
# Reading: pdf_files/2018/haziran-2018.pdf
# Reading: pdf_files/2018/mart-2018.pdf
# Reading: pdf_files/2018/temmuz-2018.pdf
# Reading: pdf_files/2018/kasim-2018.pdf
# Reading: pdf_files/2018/ekim-2018.pdf
# Reading: pdf_files/2018/aralik-2018.pdf
# Reading: pdf_files/2018/ocak-2018.pdf
# Reading: pdf_files/2018/eylul-2018.pdf
# Reading: pdf_files/2018/nisan-2018.pdf
# --------------------------------------------------
# Batch: 12
# Reading: pdf_files/2018/mayis-2018.pdf
# Reading: pdf_files/2018/agustos-2018.pdf
# Reading: pdf_files/2018/subat-2018.pdf
# Reading: pdf_files/2019/aralik-2019.pdf
# Reading: pdf_files/2019/mayis-2019.pdf
# Reading: pdf_files/2019/eylul-2019.pdf
# Reading: pdf_files/2019/kasim-2019.pdf
# Reading: pdf_files/2019/ekim-2019.pdf
# Reading: pdf_files/2019/haziran-2019.pdf
# Reading: pdf_files/2019/subat-2019.pdf
# Reading: pdf_files/2019/temmuz-2019.pdf
# Reading: pdf_files/2019/nisan-2019.pdf
# --------------------------------------------------
# Batch: 13
# Reading: pdf_files/2019/mart-2019.pdf
# Reading: pdf_files/2019/ocak-2019.pdf
# Reading: pdf_files/2019/agustos-2019.pdf
# Reading: pdf_files/2009/temmuz-2009.pdf
# Reading: pdf_files/2009/agustos-2009.pdf
# Reading: pdf_files/2009/ocak-2009.pdf
# Reading: pdf_files/2009/subat-2009.pdf
# Reading: pdf_files/2009/eylul-2009.pdf
# Reading: pdf_files/2009/aralik-2009.pdf
# Reading: pdf_files/2009/mayis-2009.pdf
# Reading: pdf_files/2009/ekim-2009.pdf
# Reading: pdf_files/2009/haziran-2009.pdf
# --------------------------------------------------
# Batch: 14
# Reading: pdf_files/2009/mart-2009.pdf
# Reading: pdf_files/2009/kasim-2009.pdf
# Reading: pdf_files/2009/nisan-2009.pdf
# Reading: pdf_files/2005/subat-2005.pdf
# Reading: pdf_files/2005/mayis-2005.pdf
# Reading: pdf_files/2005/eylul-2005.pdf
# Reading: pdf_files/2005/haziran-2005.pdf
# Reading: pdf_files/2005/ocak-2005.pdf
# Reading: pdf_files/2005/temmuz-2005.pdf
# Reading: pdf_files/2005/aralik-2005.pdf
# Reading: pdf_files/2005/mart-2005.pdf
# Reading: pdf_files/2005/kasim-2005.pdf
# --------------------------------------------------
# Batch: 15
# Reading: pdf_files/2005/nisan-2005.pdf
# Reading: pdf_files/2005/agustos-2005.pdf
# Reading: pdf_files/2005/ekim-2005.pdf
# Reading: pdf_files/2010/eylul-2010.pdf
# Reading: pdf_files/2010/agustos-2010.pdf
# Reading: pdf_files/2010/aralik-2010.pdf
# Reading: pdf_files/2010/temmuz-2010.pdf
# Reading: pdf_files/2010/ocak-2010.pdf
# Reading: pdf_files/2010/haziran-2010.pdf
# Reading: pdf_files/2010/kasim-2010.pdf
# Reading: pdf_files/2010/ekim-2010.pdf
# Reading: pdf_files/2010/nisan-2010.pdf
# --------------------------------------------------
# Batch: 16
# Reading: pdf_files/2010/subat-2010.pdf
# Reading: pdf_files/2010/mayis-2010.pdf
# Reading: pdf_files/2010/mart-2010.pdf
# Reading: pdf_files/2004/eylul-2004.pdf
# Reading: pdf_files/2004/aralik-2004.pdf
# Reading: pdf_files/2004/mart-2004.pdf
# Reading: pdf_files/2004/ekim-2004.pdf
# Reading: pdf_files/2004/temmuz-2004.pdf
# Reading: pdf_files/2004/haziran-2004.pdf
# Reading: pdf_files/2004/agustos-2004.pdf
# Reading: pdf_files/2004/nisan-2004.pdf
# Reading: pdf_files/2004/kasim-2004.pdf
# --------------------------------------------------
# Batch: 17
# Reading: pdf_files/2004/mayis-2004.pdf
# Reading: pdf_files/2004/subat-2004.pdf
# Reading: pdf_files/2004/ocak-2004.pdf
# Reading: pdf_files/2012/subat-2012.pdf
# Reading: pdf_files/2012/ekim-2012.pdf
# Reading: pdf_files/2012/nisan-2012.pdf
# Reading: pdf_files/2012/kasim-2012.pdf
# Reading: pdf_files/2012/haziran-2012.pdf
# Reading: pdf_files/2012/ocak-2012.pdf
# Reading: pdf_files/2012/aralik-2012.pdf
# Reading: pdf_files/2012/agustos-2012.pdf
# Reading: pdf_files/2012/eylul-2012.pdf
# --------------------------------------------------
# Batch: 18
# Reading: pdf_files/2012/temmuz-2012.pdf
# Reading: pdf_files/2012/mayis-2012.pdf
# Reading: pdf_files/2012/mart-2012.pdf
# Reading: pdf_files/2014/ocak-2014.pdf
# Reading: pdf_files/2014/mart-2014.pdf
# Reading: pdf_files/2014/kasim-2014.pdf
# Reading: pdf_files/2014/ekim-2014.pdf
# Reading: pdf_files/2014/mayis-2014.pdf
# Reading: pdf_files/2014/eylul-2014.pdf
# Reading: pdf_files/2014/nisan-2014.pdf
# Reading: pdf_files/2014/subat-2014.pdf
# Reading: pdf_files/2014/haziran-2014.pdf
# --------------------------------------------------
# Batch: 19
# Reading: pdf_files/2014/agustos-2014.pdf
# Reading: pdf_files/2014/temmuz-2014.pdf
# Reading: pdf_files/2014/aralik-2014.pdf
# Reading: pdf_files/2001/subat-2001.pdf
# Reading: pdf_files/2001/haziran-2001.pdf
# Reading: pdf_files/2001/mayis-2001.pdf
# Reading: pdf_files/2001/kasim-2001.pdf
# Reading: pdf_files/2001/mart-2001.pdf
# Reading: pdf_files/2001/nisan-2001.pdf
# Reading: pdf_files/2001/ocak-2001.pdf
# Reading: pdf_files/2001/ekim-2001.pdf
# Reading: pdf_files/2001/eylul-2001.pdf
# --------------------------------------------------
# Batch: 20
# Reading: pdf_files/2001/aralik-2001.pdf
# Reading: pdf_files/2001/temmuz-2001.pdf
# Reading: pdf_files/2001/agustos-2001.pdf
# Reading: pdf_files/2016/nisan-2016.pdf
# Reading: pdf_files/2016/haziran-2016.pdf
# Reading: pdf_files/2016/eylul-2016.pdf
# Reading: pdf_files/2016/mart-2016.pdf
# Reading: pdf_files/2016/mayis-2016.pdf
# Reading: pdf_files/2016/agustos-2016.pdf
# Reading: pdf_files/2016/subat-2016.pdf
# Reading: pdf_files/2016/aralik-2016.pdf
# Reading: pdf_files/2016/ocak-2016.pdf
# --------------------------------------------------
# Batch: 21
# Reading: pdf_files/2016/temmuz-2016.pdf
# Reading: pdf_files/2016/kasim-2016.pdf
# Reading: pdf_files/2016/ekim-2016.pdf
# --------------------------------------------------
